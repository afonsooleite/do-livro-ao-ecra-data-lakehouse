# %%
#Instalar delta-spark 
# !pip install delta-spark==2.4.0
# Out:
# Requirement already satisfied: delta-spark==2.4.0 in /opt/conda/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: pyspark<3.5.0,>=3.4.0 in /usr/local/spark/python (from delta-spark==2.4.0) (3.4.1)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from delta-spark==2.4.0) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=1.0.0->delta-spark==2.4.0) (3.16.2)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.11/site-packages (from pyspark<3.5.0,>=3.4.0->delta-spark==2.4.0) (0.10.9.7)

# %%
#Imports + sessão Spark configurada (warehouse + hive + delta)

from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip
from pyspark.sql.functions import col, trim, lower

# Configuração da Sessão Spark
warehouse_location = "hdfs://hdfs-nn:9000/warehouse"

builder = (
    SparkSession.builder
    .appName("Fase Gold - series_avaliadas")
    .config("spark.sql.warehouse.dir", warehouse_location)
    .config("hive.metastore.uris", "thrift://hive-metastore:9083")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0")
    .enableHiveSupport()
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()
print("Sessão Spark (Gold) iniciada com sucesso.")
# Out:
# Sessão Spark (Gold) iniciada com sucesso.

# %%
#Confirmar se a BD gold existe; se não existir, criar

print("A criar/usar a base de dados 'gold'...")
spark.sql("CREATE DATABASE IF NOT EXISTS gold LOCATION 'hdfs://hdfs-nn:9000/warehouse/gold.db/'")
spark.sql("USE gold")
# Out:
# A criar/usar a base de dados 'gold'...
# DataFrame[]

# %%
#ler as tabelas da Silver (tv_shows e rating_shows)

df_tv_shows = spark.table("silver.tv_shows")
df_rating_shows = spark.table("silver.rating_shows")

print("tv_shows colunas:", df_tv_shows.columns)
print("rating_shows colunas:", df_rating_shows.columns)

print("\nAmostra tv_shows:")
df_tv_shows.show(5, truncate=False)

print("\nAmostra rating_shows:")
df_rating_shows.show(5, truncate=False)
# Out:
# tv_shows colunas: ['id', 'series_name', 'first_air_date', 'popularity', 'vote_average', 'vote_count']
# rating_shows colunas: ['show', 'review', 'sentiment', 'review_type']
#
# Amostra tv_shows:
# +------+--------------------+--------------+----------+------------+----------+
# |id    |series_name         |first_air_date|popularity|vote_average|vote_count|
# +------+--------------------+--------------+----------+------------+----------+
# |96246 |#LikeMe             |2019-01-13    |10.066    |9.7         |3         |
# |2211  |'Allo 'Allo!        |1984-09-07    |28.808    |7.8         |162       |
# |1568  |'Til Death          |2006-09-07    |9.945     |6.6         |44        |
# |203417|'Til Jail Do Us Part|2022-09-15    |116.136   |7.6         |5         |
# |8864  |.hack               |2002-04-04    |16.699    |6.8         |21        |
# +------+--------------------+--------------+----------+------------+----------+
# only showing top 5 rows
#
#
# Amostra rating_shows:
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |show    |review                                                                                                                                                                                                                              |sentiment|review_type|
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |11.22.63|11.22.63 reaches some thoughtful moving conclusions but oh what coulda been with a more engaged star. if only there were a time machine to fix that mistake.                                                                        |0        |critic     |
# |11.22.63|11.22.63 sets forth with a fascinating premise but gets a little too distracted by superfluous material that only causes it to get sidetracked from the main plot resulting in a slightly unfocused show with problematic execution.|0        |critic     |
# |11.22.63|awkward and flat never matching the promise of its premise.                                                                                                                                                                         |0        |critic     |
# |11.22.63|feels like something abc might have aired in 1997.                                                                                                                                                                                  |0        |critic     |
# |11.22.63|i'm still not entirely convinced about 11.22.63 just yet. while i have always enjoyed franco as an actor i'm not getting the sense of conviction that i got from book-jake.                                                         |0        |critic     |
# +--------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, trim, lower

# normalizar colunas
df_tv_shows_clean = df_tv_shows.withColumn("series_name", lower(trim(col("series_name"))))
df_rating_shows_clean = df_rating_shows.withColumn("show", lower(trim(col("show"))))

# usar alias + col() na condição do join (mais seguro)
tv = df_tv_shows_clean.alias("tv")
rt = df_rating_shows_clean.alias("rt")

df_series_avaliadas_tmp = tv.join(
    rt,
    col("tv.series_name") == col("rt.show"),
    how="inner"
)

print("Linhas após junção:", df_series_avaliadas_tmp.count())
df_series_avaliadas_tmp.show(5, truncate=False)
# Out:
# Linhas após junção: 76164
# +-----+-----------+--------------+----------+------------+----------+--------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |id   |series_name|first_air_date|popularity|vote_average|vote_count|show    |review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |sentiment|review_type|
# +-----+-----------+--------------+----------+------------+----------+--------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |11.22.63|"just wasted 8 hours of our lives on this rediculously drawn out ""back to the past"" mini series. nothing about it held up in even given time travel is a fantasy.why james franco would be involved with this stupid project is beyond medon't make the mistake we did!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |11.22.63|king's book is a masterpiece but the series is lousy. its main flaw is in the script; the numerous changes and additions to the book are useless clumsy distracting. much is taken away from the book's plot even parts that would make excellent cinematic material. the original characters are flattened the new ones are poor often inconsistent. the acting of mr. franco is embarrassing. the book was poignant and compelling; the series is a sad travesty of it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |11.22.63|trash! absolute garbage! what a waste of such an amazing story! anyone who has read the book should not watch this as it will only lessen your opinion of 11.22.63 and waste 8 hours of your life. it couldn't have been worse. the story is so twisted from the novel that i wonder how or why stephen king signed off on this pos! yes. it's that bad!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |11.22.63|what a disappointment  so unbalanced like a soap opera from 1963                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |11.22.63|"sure  the lead actors were great as far acting goes i'm cutting to the chase: totally missed the mark on digging into the theories/conflicting stories behind the jfk assassination. this could have been an intriguing concept of time travel had they not filled the episodes full of standard default sub-plots of soap drama junk food. further had the writers stayed the course of focusing in on who all was potentitally involved in this ""conspiracy"" to kill the president again rather than sticking to the life magazine version of the story (that oswald was the lone nut job with the golden bullet) the story could have been powerful. the grassy knoll along with many other possible characters involved was barely even mentioned and or totally left out. either this is just plain embarrassingly bad entertainment or a high mark at what hollywood does best : provide pure propaganda fictions that ultimately become the ""history""  they want us to believe.   but sure  the lead actors were great."|negative |audience   |
# +-----+-----------+--------------+----------+------------+----------+--------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# only showing top 5 rows

# %%
#Fundir as colunas show e series_name
from pyspark.sql.functions import coalesce

df_series_avaliadas = (
    df_series_avaliadas_tmp
    .withColumn("series_name", coalesce(col("tv.series_name"), col("rt.show")))
    .drop(col("rt.show"))
)

# %%
#Guardar na gold.db como tabela Delta (series_avaliadas)

df_series_avaliadas.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.series_avaliadas")

print("Tabela 'gold.series_avaliadas' gravada com sucesso!")
# Out:
# Tabela 'gold.series_avaliadas' gravada com sucesso!

# %%
#Confirmar que ficou mesmo na gold + preview

spark.sql("SHOW TABLES IN gold").show(truncate=False)

df_check = spark.table("gold.series_avaliadas")
print("Contagem final na gold.series_avaliadas:", df_check.count())
df_check.show(20, truncate=False)
# Out:
# +---------+----------------+-----------+
# |namespace|tableName       |isTemporary|
# +---------+----------------+-----------+
# |gold     |series_adaptadas|false      |
# |gold     |series_avaliadas|false      |
# +---------+----------------+-----------+
#
# Contagem final na gold.series_avaliadas: 76164
# +-----+-----------+--------------+----------+------------+----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |id   |series_name|first_air_date|popularity|vote_average|vote_count|review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |sentiment|review_type|
# +-----+-----------+--------------+----------+------------+----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |"just wasted 8 hours of our lives on this rediculously drawn out ""back to the past"" mini series. nothing about it held up in even given time travel is a fantasy.why james franco would be involved with this stupid project is beyond medon't make the mistake we did!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |king's book is a masterpiece but the series is lousy. its main flaw is in the script; the numerous changes and additions to the book are useless clumsy distracting. much is taken away from the book's plot even parts that would make excellent cinematic material. the original characters are flattened the new ones are poor often inconsistent. the acting of mr. franco is embarrassing. the book was poignant and compelling; the series is a sad travesty of it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |trash! absolute garbage! what a waste of such an amazing story! anyone who has read the book should not watch this as it will only lessen your opinion of 11.22.63 and waste 8 hours of your life. it couldn't have been worse. the story is so twisted from the novel that i wonder how or why stephen king signed off on this pos! yes. it's that bad!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |what a disappointment  so unbalanced like a soap opera from 1963                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |"sure  the lead actors were great as far acting goes i'm cutting to the chase: totally missed the mark on digging into the theories/conflicting stories behind the jfk assassination. this could have been an intriguing concept of time travel had they not filled the episodes full of standard default sub-plots of soap drama junk food. further had the writers stayed the course of focusing in on who all was potentitally involved in this ""conspiracy"" to kill the president again rather than sticking to the life magazine version of the story (that oswald was the lone nut job with the golden bullet) the story could have been powerful. the grassy knoll along with many other possible characters involved was barely even mentioned and or totally left out. either this is just plain embarrassingly bad entertainment or a high mark at what hollywood does best : provide pure propaganda fictions that ultimately become the ""history""  they want us to believe.   but sure  the lead actors were great."                                                                                                                                                                                                                          |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |crushed the expectations by making it more of a love story than a sci-fi thriller.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |every frame a beautiful portrait - which is a shame because the show itself is so so lame and boring. the book wasn't that great but somehow they managed to make it much much worse.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |performances are subpar pacing is horrible the characters that weren't in the book but added for the series are pointless and distracting. overall disappointing.however compelling enough to keep me watching throughout the whole series.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |why oh why has stephen king allowed the story line to be changed so much...and certainly not for the better. i enjoyed the book so much but this is a pale imitation. what the hell is the sidekick doing in 1962 and what happened to the very low profile jake epping has to keep? not impressed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |i was extremely disappointed in the mini-series. i should disclose that i read the book but i am not sure i would have liked it any better if that was not the case. i should also disclose that i  am a fan of bad robot jj abrams stephen king and james franco so i was really rooting for a home run here. unfortunately all of the nuance that made you care about the characters and plot in the print version was removed or glossed over in the tv version. i realize there are time constraints that force certain creative decisions but in all honesty i have just finished episode 7 and i don't know if i am rooting for lee harvey oswald or not at this point.  the decisions they made on what to leave and what to trim make no sense. they left in things that were important to the book version but do nothing to further the tv version of the story and removed important elements that would go a long way toward explaining what is going on in the tv version to make room for a story about a janitor no one cares about unless they read the book.. instead of making a tv series that could stand on its own the creators have made a mini-series that is based upon a cliff notes version of the book that is not nearly as good..|negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |interesting premise for a show but i have no idea what happens when i start a new episode. ridiculous.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |james franco delivers a poor performance as jake in the lead role guy who plays bill is ever increasingly annoying and lee harvey oswald's accent in the show is too difficult to understand.  shocked this received positive reviews.  poor show.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |pretty bad.  poorly paced.  very bad acting by james franco.  some of the supporting actors are pretty good but overall just a poor effort all around.  want something i liked?  in the final episode the yellow card man spins a little story in the car with james franco.  it probably lasts all of a minute.  and yet the actor blows james franco off the screen with his performance.  if the rest had been that good oh boy.  but it isn't.  i simply slogged through the final three episodes to see how it finished and whether it had the same ending as the book or not.  yeesh!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |this thing crashes disastrously somewhere on the 2nd or 3rd part. i can't figure what made king take a perfectly good story flatten the hell out of it make up all these ridiculous side plots that weren't there to begin with and practically kill the story. everything here is just so off. i couldn't even force myself to the last part being so disinterested as i got. do yourself a favor and read the book.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |"i had big expectations about this serie but i'm sorry to say that it's a poor product. everything is so wrong! i know that as a ""constant reader"" you can't expect to find exactly what king has written but the story is so different that makes me sad. franco has only 2 expressions: romantically happy or terrified. gadon is a ninny. the only thing i really like is the secondary cast: webber is a perfect oswald duhamel is a beautifully crazy ex husband and annetto o'toole is such an adorable (and gorgeous) landlord. in the end i'm disappointed."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |a time travel tale gone wrong. like the dead zone 11.22.63 is about assassination. but this time there is time travelling involved to go back to the time when kennedy was killed. no one really cares and the story is not particularly compelling. franco was really bad at playing the lead role. overall it's not something worth wasting 8 hours of your life on.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |after you learn what the objective is in the show you realize that the series is one big plot hole. some interesting situations arise but that might not be enough to fuel me through the last two episodes.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |at about 7 hours it is easy way too long.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |i'm not familiar with the source content but the direction of the show is absurd. you have amazing plot devices at your disposal; time travel a possible conspiracy the cold war the mafia the cia or the potential for some other nefarious group yet we spend 1/2 of the series (4 out of 8 episodes) on domestic abuse? yikes. had me at episode one. lost me by ep. 4.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |negative |audience   |
# |64464|11.22.63   |2016-02-15    |23.014    |7.8         |1162      |interesting premise but execution lacking. the story goes off the rails very quickly and franco becomes just another fanatical nut. and who's this woman and why is she here? a normal person would have reported him to the cops or fbi long ago. great period piece with the authentic cars and costumes and the southern racism. what could have been.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |negative |audience   |
# +-----+-----------+--------------+----------+------------+----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import concat_ws, col

df = spark.table("gold.series_avaliadas")

df.coalesce(1) \
  .write \
  .mode("overwrite") \
  .option("header", "true") \
  .csv("/tmp/series_avaliadas_csv")

# %%
# !ls /tmp/series_avaliadas_csv
# Out:
# part-00000-bbb9d184-5d29-4835-88ad-a6a53cd47102-c000.csv  _SUCCESS

# %%
# !cp /tmp/series_avaliadas_csv/part-00000-bbb9d184-5d29-4835-88ad-a6a53cd47102-c000.csv /home/jovyan/series_avaliadas.csv
# !ls -lah /home/jovyan/series_avaliadas.csv
# Out:
# -rw-r--r-- 1 jovyan users 26M Dec 28 11:15 /home/jovyan/series_avaliadas.csv
