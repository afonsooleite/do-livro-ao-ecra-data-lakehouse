# %%
# !pip install delta-spark==2.4.0
# Out:
# Requirement already satisfied: delta-spark==2.4.0 in /opt/conda/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: pyspark<3.5.0,>=3.4.0 in /usr/local/spark/python (from delta-spark==2.4.0) (3.4.1)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from delta-spark==2.4.0) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=1.0.0->delta-spark==2.4.0) (3.16.2)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.11/site-packages (from pyspark<3.5.0,>=3.4.0->delta-spark==2.4.0) (0.10.9.7)

# %%
from pyspark.sql import SparkSession
from delta import configure_spark_with_delta_pip

warehouse_location = "hdfs://hdfs-nn:9000/warehouse"

builder = (
    SparkSession.builder
    .appName("Fase Gold - desempenho_livros")
    .config("spark.sql.warehouse.dir", warehouse_location)
    .config("hive.metastore.uris", "thrift://hive-metastore:9083")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0")
    .enableHiveSupport()
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()
print("Sessão Spark (Gold) iniciada com sucesso.")
# Out:
# Sessão Spark (Gold) iniciada com sucesso.

# %%
print("A criar/usar a base de dados 'gold'...")
spark.sql("CREATE DATABASE IF NOT EXISTS gold LOCATION 'hdfs://hdfs-nn:9000/warehouse/gold.db/'")
spark.sql("USE gold")
# Out:
# A criar/usar a base de dados 'gold'...
# DataFrame[]

# %%
df_books = spark.table("silver.books")
df_adap  = spark.table("silver.adaptations")

print("books colunas:", df_books.columns)
print("adaptations colunas:", df_adap.columns)

print("\nAmostra books:")
df_books.show(5, truncate=False)

print("\nAmostra adaptations:")
df_adap.show(5, truncate=False)
# Out:
# books colunas: ['book_id', 'book_title', 'author', 'book_rating', 'ratings_count', 'text_reviews_count', 'publication_year', 'publisher']
# adaptations colunas: ['author', 'book_title', 'movie_title', 'movie_year']
#
# Amostra books:
# +-------+---------------------------------------------------------+--------------------------+-----------+-------------+------------------+----------------+---------------+
# |book_id|book_title                                               |author                    |book_rating|ratings_count|text_reviews_count|publication_year|publisher      |
# +-------+---------------------------------------------------------+--------------------------+-----------+-------------+------------------+----------------+---------------+
# |1      |harry potter and the halfblood prince harry potter  6    |J.K. Rowling/Mary GrandPré|4.57       |2095690      |27591             |2006            |Scholastic Inc.|
# |2      |harry potter and the order of the phoenix harry potter  5|J.K. Rowling/Mary GrandPré|4.49       |2153167      |29221             |2004            |Scholastic Inc.|
# |4      |harry potter and the chamber of secrets harry potter  2  |J.K. Rowling              |4.42       |6333         |244               |2003            |Scholastic     |
# |5      |harry potter and the prisoner of azkaban harry potter  3 |J.K. Rowling/Mary GrandPré|4.56       |2339585      |36325             |2004            |Scholastic Inc.|
# |8      |harry potter boxed set  books 15 harry potter  15        |J.K. Rowling/Mary GrandPré|4.78       |41428        |164               |2004            |Scholastic     |
# +-------+---------------------------------------------------------+--------------------------+-----------+-------------+------------------+----------------+---------------+
# only showing top 5 rows
#
#
# Amostra adaptations:
# +-----------------+-----------------------------------+------------------------------------------------------------+----------+
# |author           |book_title                         |movie_title                                                 |movie_year|
# +-----------------+-----------------------------------+------------------------------------------------------------+----------+
# |el james         |null                               |fifty shades darker                                         |2017      |
# |el james         |null                               |fifty shades freed                                          |2018      |
# |alexandra bracken|null                               |the darkest minds                                           |2018      |
# |cs lewis         |the lion the witch and the wardrobe|the chronicles of narnia the lion the witch and the wardrobe|2005      |
# |victor hugo      |les miserables                     |les miserables                                              |1935      |
# +-----------------+-----------------------------------+------------------------------------------------------------+----------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import (
    col, trim, lower, countDistinct,
    min as Fmin, max as Fmax,
    collect_set, size, first
)


# 0) DataFrames de origem

df_books = spark.table("silver.books")
df_adap  = spark.table("silver.adaptations")

# 1) Colunas de join (existem mesmo)

bk_col = "book_title"
ad_col = "book_title"

print("Coluna usada em books:", bk_col)
print("Coluna usada em adaptations:", ad_col)

# 2) Normalizar chave + aliases

b = (
    df_books.alias("b")
    .withColumn("book_key", lower(trim(col(bk_col))))
    .withColumn("author_key", lower(trim(col("author"))))
)

a = (
    df_adap.alias("a")
    .withColumn("book_key", lower(trim(col(ad_col))))
    .withColumn("author_key", lower(trim(col("author"))))
)

# 3) Join (por título + autor)

df_join = (
    b.join(
        a,
        on=["book_key", "author_key"],
        how="left"
    )
)

print("Linhas após junção:", df_join.count())
df_join.select(
    "b.book_id", "b.book_title", "b.author",
    "a.movie_title", "a.movie_year"
).show(10, truncate=False)

# 4) Agregações de adaptações

aggs = [
    countDistinct(col("a.movie_title")).alias("num_adaptacoes"),
    size(collect_set(col("a.movie_title"))).alias("num_filmes_distintos"),
    collect_set(col("a.movie_title")).alias("filmes"),
    Fmin(col("a.movie_year")).alias("primeiro_ano_filme"),
    Fmax(col("a.movie_year")).alias("ultimo_ano_filme"),
]

# 5) GOLD: desempenho_livros

df_desempenho_livros = (
    df_join
    .groupBy(
        "book_key",
        col("b.book_id").alias("book_id")
    )
    .agg(
        first(col("b.book_title"), ignorenulls=True).alias("book_title"),
        first(col("b.author"), ignorenulls=True).alias("author"),
        first(col("b.publisher"), ignorenulls=True).alias("publisher"),
        first(col("b.publication_year"), ignorenulls=True).alias("publication_year"),
        first(col("b.book_rating"), ignorenulls=True).alias("book_rating"),
        first(col("b.ratings_count"), ignorenulls=True).alias("ratings_count"),
        first(col("b.text_reviews_count"), ignorenulls=True).alias("text_reviews_count"),
        *aggs
    )
)

print("Preview df_desempenho_livros:")
df_desempenho_livros.show(20, truncate=False)
# Out:
# Coluna usada em books: book_title
# Coluna usada em adaptations: book_title
# Linhas após junção: 11124
# +-------+-----------------------------------------------------------------------------------------------------+--------------------------+-----------+----------+
# |book_id|book_title                                                                                           |author                    |movie_title|movie_year|
# +-------+-----------------------------------------------------------------------------------------------------+--------------------------+-----------+----------+
# |1      |harry potter and the halfblood prince harry potter  6                                                |J.K. Rowling/Mary GrandPré|null       |null      |
# |2      |harry potter and the order of the phoenix harry potter  5                                            |J.K. Rowling/Mary GrandPré|null       |null      |
# |4      |harry potter and the chamber of secrets harry potter  2                                              |J.K. Rowling              |null       |null      |
# |5      |harry potter and the prisoner of azkaban harry potter  3                                             |J.K. Rowling/Mary GrandPré|null       |null      |
# |8      |harry potter boxed set  books 15 harry potter  15                                                    |J.K. Rowling/Mary GrandPré|null       |null      |
# |9      |unauthorized harry potter book seven news halfblood prince analysis and speculation                  |W. Frederick Zimmerman    |null       |null      |
# |10     |harry potter collection harry potter  16                                                             |J.K. Rowling              |null       |null      |
# |12     |the ultimate hitchhikers guide five complete novels and one story hitchhikers guide to the galaxy  15|Douglas Adams             |null       |null      |
# |13     |the ultimate hitchhikers guide to the galaxy hitchhikers guide to the galaxy  15                     |Douglas Adams             |null       |null      |
# |14     |the hitchhikers guide to the galaxy hitchhikers guide to the galaxy  1                               |Douglas Adams             |null       |null      |
# +-------+-----------------------------------------------------------------------------------------------------+--------------------------+-----------+----------+
# only showing top 10 rows
#
# Preview df_desempenho_livros:
# +--------------------------------------------------------------------------------------------------+-------+--------------------------------------------------------------------------------------------------+------------------------------------------------------+--------------------------+----------------+-----------+-------------+------------------+--------------+--------------------+------+------------------+----------------+
# |book_key                                                                                          |book_id|book_title                                                                                        |author                                                |publisher                 |publication_year|book_rating|ratings_count|text_reviews_count|num_adaptacoes|num_filmes_distintos|filmes|primeiro_ano_filme|ultimo_ano_filme|
# +--------------------------------------------------------------------------------------------------+-------+--------------------------------------------------------------------------------------------------+------------------------------------------------------+--------------------------+----------------+-----------+-------------+------------------+--------------+--------------------+------+------------------+----------------+
# |                                                                                                  |14731  |                                                                                                  |Ha Jin/季思聰                                         |時報出版                  |2005            |3.79       |1            |0                 |0             |0                   |[]    |null              |null            |
# |                                                                                                  |15294  |                                                                                                  |J.R.R. Tolkien/托爾金/Alan  Lee/朱學恆                |聯經出版事業股份有限公司  |2001            |4.36       |26           |0                 |0             |0                   |[]    |null              |null            |
# |                                                                                                  |15318  |                                                                                                  |J.R.R. Tolkien/托爾金/Alan  Lee/朱學恆                |聯經出版事業股份有限公司  |2001            |4.44       |24           |0                 |0             |0                   |[]    |null              |null            |
# |                                                                                                  |17837  |                                                                                                  |Mikhail Bulgakov/Михаил Булгаков                      |Эксмо                     |2004            |4.3        |10           |1                 |0             |0                   |[]    |null              |null            |
# |1                                                                                                 |22817  | 1                                                                                                |Rumiko Takahashi                                      |小学館                    |1997            |4.27       |41           |3                 |0             |0                   |[]    |null              |null            |
# |1                                                                                                 |31992  | 1                                                                                                |Hiromu Arakawa/荒川弘/方郁仁                          |東立                      |2004            |4.5        |9            |1                 |0             |0                   |[]    |null              |null            |
# |1                                                                                                 |34241  | 1                                                                                                |Takashi Hashiguchi/橋口 たかし                        |小学館                    |2002            |3.97       |6            |0                 |0             |0                   |[]    |null              |null            |
# |1 000 places to see before you die                                                                |11525  |1 000 places to see before you die                                                                |Patricia Schultz                                      |Workman Publishing Company|2003            |3.85       |36303        |439               |0             |0                   |[]    |null              |null            |
# |1 cldx                                                                                            |26836  | 1 cldx                                                                                           |Satosumi Takaguchi/Satosumi Takaguchi                 |角川書店 (Kadokawa Shoten)|1996            |3.68       |2            |0                 |0             |0                   |[]    |null              |null            |
# |1 hagane no renkinjutsushi 1 fullmetal alchemist  1                                               |37051  | 1 hagane no renkinjutsushi 1 fullmetal alchemist  1                                              |Hiromu Arakawa                                        |ガンガンコミックス        |2002            |4.5        |56           |10                |0             |0                   |[]    |null              |null            |
# |10                                                                                                |22816  | 10                                                                                               |Rumiko Takahashi                                      |小学館                    |1999            |4.28       |15           |0                 |0             |0                   |[]    |null              |null            |
# |10                                                                                                |31994  | 10                                                                                               |Hiromu Arakawa/荒川弘/方郁仁                          |東立                      |2005            |4.6        |3            |0                 |0             |0                   |[]    |null              |null            |
# |10 lb penalty                                                                                     |8542   |10 lb penalty                                                                                     |Dick Francis                                          |G.P. Putnam's Sons        |2004            |3.9        |3490         |177               |0             |0                   |[]    |null              |null            |
# |100 great fantasy short short stories                                                             |41840  |100 great fantasy short short stories                                                             |Isaac Asimov/Terry Carr/Martin H. Greenberg/Janet  Fox|Avon                      |1985            |3.91       |204          |19                |0             |0                   |[]    |null              |null            |
# |100 love sonnets                                                                                  |11339  |100 love sonnets                                                                                  |Pablo Neruda/Stephen Tapscott                         |University of Texas Press |1986            |4.39       |12613        |392               |0             |0                   |[]    |null              |null            |
# |100 years of lynchings                                                                            |313    |100 years of lynchings                                                                            |Ralph Ginzburg                                        |Black Classic Press       |1996            |4.61       |88           |4                 |0             |0                   |[]    |null              |null            |
# |1000 record covers                                                                                |576    |1000 record covers                                                                                |Michael Ochs/Patrick Javault/Ulrike Wasel             |Taschen                   |2005            |3.85       |288          |31                |0             |0                   |[]    |null              |null            |
# |1000 rings inspiring adornments for the hand                                                      |25806  |1000 rings inspiring adornments for the hand                                                      |Marthe Le Van/Robert W. Ebendorf/Lark Books           |Lark Books                |2004            |4.23       |82           |9                 |0             |0                   |[]    |null              |null            |
# |1001 illuminated initial letters 27 fullcolor plates                                              |32197  |1001 illuminated initial letters 27 fullcolor plates                                              |Owen    Jones                                         |Dover Publications        |1988            |3.46       |11           |1                 |0             |0                   |[]    |null              |null            |
# |101 stories of the great ballets the scenebyscene stories of the most popular ballets  old and new|9156   |101 stories of the great ballets the scenebyscene stories of the most popular ballets  old and new|George Balanchine/Francis Mason                       |Anchor                    |1975            |4.0        |203          |12                |0             |0                   |[]    |null              |null            |
# +--------------------------------------------------------------------------------------------------+-------+--------------------------------------------------------------------------------------------------+------------------------------------------------------+--------------------------+----------------+-----------+-------------+------------------+--------------+--------------------+------+------------------+----------------+
# only showing top 20 rows

# %%
df_desempenho_livros.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("gold.desempenho_livros")

print("Tabela 'gold.desempenho_livros' gravada com sucesso!")
# Out:
# Tabela 'gold.desempenho_livros' gravada com sucesso!

# %%
from pyspark.sql.functions import concat_ws, col

df = spark.table("gold.desempenho_livros")

df_export = df.withColumn("filmes", concat_ws(" | ", col("filmes")))  

df_export.coalesce(1) \
    .write \
    .mode("overwrite") \
    .option("header", "true") \
    .csv("/tmp/desempenho_livros_csv")

# %%
spark.table("gold.desempenho_livros").printSchema()
# Out:
# root
#  |-- book_key: string (nullable = true)
#  |-- book_id: integer (nullable = true)
#  |-- book_title: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- publication_year: integer (nullable = true)
#  |-- book_rating: double (nullable = true)
#  |-- ratings_count: integer (nullable = true)
#  |-- text_reviews_count: integer (nullable = true)
#  |-- num_adaptacoes: long (nullable = true)
#  |-- num_filmes_distintos: integer (nullable = true)
#  |-- filmes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- primeiro_ano_filme: integer (nullable = true)
#  |-- ultimo_ano_filme: integer (nullable = true)

# %%
# !ls /tmp/desempenho_livros_csv
# Out:
# part-00000-0f733d77-2c0d-42d8-ba57-838ae6c39217-c000.csv  _SUCCESS

# %%
# !cp /tmp/desempenho_livros_csv/part-00000-0f733d77-2c0d-42d8-ba57-838ae6c39217-c000.csv /home/jovyan/desempenho_livros.csv
# !ls -lah /home/jovyan/desempenho_livros.csv
# Out:
# -rw-r--r-- 1 jovyan users 1.6M Dec 28 12:53 /home/jovyan/desempenho_livros.csv
