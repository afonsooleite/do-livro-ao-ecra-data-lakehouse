# %%
# Instalar delta-spark
# !pip install delta-spark==2.4.0
# Out:
# Requirement already satisfied: delta-spark==2.4.0 in /opt/conda/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: pyspark<3.5.0,>=3.4.0 in /usr/local/spark/python (from delta-spark==2.4.0) (3.4.1)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from delta-spark==2.4.0) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=1.0.0->delta-spark==2.4.0) (3.16.2)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.11/site-packages (from pyspark<3.5.0,>=3.4.0->delta-spark==2.4.0) (0.10.9.7)

# %%
#Início da sessão Spark (Hive + Delta)
from pyspark.sql import SparkSession

warehouse_location = "hdfs://hdfs-nn:9000/warehouse"

spark = (
    SparkSession.builder
        .appName("Silver_Audience_Reviews")
        .config("spark.sql.warehouse.dir", warehouse_location)
        .config("hive.metastore.uris", "thrift://hive-metastore:9083")
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
        .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0")
        .enableHiveSupport()
        .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8abd57bb9b75:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Silver_Audience_Reviews</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Schema e leitura do CSV bronze
from pyspark.sql.types import StructType, StructField, StringType, FloatType

bronze_path = "hdfs://hdfs-nn:9000/demo/bronze/audience_reviews.csv"

audience_schema = StructType([
    StructField("show",   StringType(), True),
    StructField("rating", FloatType(),  True),
    StructField("review", StringType(), True)
])

df_bronze = (
    spark.read
        .option("header", True)
        .schema(audience_schema)
        .csv(bronze_path)
)

print("----- Bronze audience_reviews (amostra) -----")
df_bronze.show(10, truncate=False)
df_bronze.printSchema()
# Out:
# ----- Bronze audience_reviews (amostra) -----
# +----+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show|rating|review                                                                                                                                                                                                                                                                                                  |
# +----+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Test|0.0   |Test review                                                                                                                                                                                                                                                                                             |
# |Loot|2.5   |I love the stars but the show is riddled with cliche characters and comedy beats as well as relentlessly predictable story lines. These feel like characters who are shorthand for characters we've already seen which sometimes is the curse of a new TV show especially sitcoms. So I guess we'll see?|
# |Loot|4.5   |Great show to watch. It's something that's easy and light hearted with a great budget. I really appreciate the cinematography used as it's different from what's usually on television.                                                                                                                 |
# |Loot|0.5   |Another Apple tanker crashes into the reef with amazing talent and a story that goes nowhere . Invasion  Foundation Physical After Party and now Loot.  Its good they have neough money to keep failing.                                                                                                |
# |Loot|4.5   |This is such a fun endearing show.  It has a lot of little jokes baked in that do not feel cheesy even though the whole setting is silly and the plot is predictable.  It makes me feel like I'm hanging out with good friends.  Maya Rudolph is perfect in the role.                                   |
# |Loot|0.5   |Terrible show - didn't laugh once. Acting is sub-par and not sure why it is continuing -                                                                                                                                                                                                                |
# |Loot|1.0   |I love Maya Rudolph but geez this was boring and did not give her anything to work with                                                                                                                                                                                                                 |
# |Loot|1.5   |I tried to enjoy the show - but it's just stupid                                                                                                                                                                                                                                                        |
# |Loot|0.5   |Love ya Maya but #comeonman.                                                                                                                                                                                                                                                                            |
# |Loot|4.0   |So far I am loving it. Maya Rudolph and Joel Kim Booster are amazing.                                                                                                                                                                                                                                   |
# +----+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# root
#  |-- show: string (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- review: string (nullable = true)

# %%
#Cria base de dados se não existir
spark.sql(f"""
    CREATE DATABASE IF NOT EXISTS silver
    LOCATION '{warehouse_location}/silver.db'
""")

spark.sql("SHOW DATABASES").show(truncate=False)
# Out:
# +---------+
# |namespace|
# +---------+
# |default  |
# |gold     |
# |silver   |
# +---------+

# %%
# Transformações para Silver
from pyspark.sql.functions import col, lower, when
from pyspark.sql.window import Window
from pyspark.sql import functions as F

# 1) Adicionar row_number para identificar a primeira linha
w_all = Window.orderBy("show", "rating", "review")
df_with_rn = df_bronze.withColumn("rn", F.row_number().over(w_all))

# 2) Remover a primeira linha (linha de teste)
df_no_test = df_with_rn.filter(col("rn") > 1).drop("rn")

# 3) Garantir que rating é double e classificá-lo como positive/negative
df_clean = df_no_test.withColumn("rating", col("rating").cast("double"))

df_clean = df_clean.withColumn(
    "rating",
    when(col("rating") >= 2.5, "positive").otherwise("negative")  # <-- minúsculas
)

# 4) Normalizar tudo para minúsculas em show e review
df_clean = (
    df_clean
        .withColumn("show", lower(col("show")))
        .withColumn("review", lower(col("review")))
)

# 5) Remover linhas duplicadas depois das transformações
df_clean = df_clean.dropDuplicates()

print("----- Silver audience_reviews (após transformações) -----")
df_clean.show(10, truncate=False)
df_clean.printSchema()
# Out:
# ----- Silver audience_reviews (após transformações) -----
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show    |rating  |review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |11.22.63|negative|"just wasted 8 hours of our lives on this rediculously drawn out ""back to the past"" mini series. nothing about it held up in even given time travel is a fantasy.why james franco would be involved with this stupid project is beyond medon't make the mistake we did!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |11.22.63|negative|king's book is a masterpiece but the series is lousy. its main flaw is in the script; the numerous changes and additions to the book are useless clumsy distracting. much is taken away from the book's plot even parts that would make excellent cinematic material. the original characters are flattened the new ones are poor often inconsistent. the acting of mr. franco is embarrassing. the book was poignant and compelling; the series is a sad travesty of it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |11.22.63|negative|trash! absolute garbage! what a waste of such an amazing story! anyone who has read the book should not watch this as it will only lessen your opinion of 11.22.63 and waste 8 hours of your life. it couldn't have been worse. the story is so twisted from the novel that i wonder how or why stephen king signed off on this pos! yes. it's that bad!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |11.22.63|negative|what a disappointment  so unbalanced like a soap opera from 1963                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |11.22.63|negative|"sure  the lead actors were great as far acting goes i'm cutting to the chase: totally missed the mark on digging into the theories/conflicting stories behind the jfk assassination. this could have been an intriguing concept of time travel had they not filled the episodes full of standard default sub-plots of soap drama junk food. further had the writers stayed the course of focusing in on who all was potentitally involved in this ""conspiracy"" to kill the president again rather than sticking to the life magazine version of the story (that oswald was the lone nut job with the golden bullet) the story could have been powerful. the grassy knoll along with many other possible characters involved was barely even mentioned and or totally left out. either this is just plain embarrassingly bad entertainment or a high mark at what hollywood does best : provide pure propaganda fictions that ultimately become the ""history""  they want us to believe.   but sure  the lead actors were great."                                                                                                                                                                                                                          |
# |11.22.63|negative|crushed the expectations by making it more of a love story than a sci-fi thriller.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |11.22.63|negative|every frame a beautiful portrait - which is a shame because the show itself is so so lame and boring. the book wasn't that great but somehow they managed to make it much much worse.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |11.22.63|negative|performances are subpar pacing is horrible the characters that weren't in the book but added for the series are pointless and distracting. overall disappointing.however compelling enough to keep me watching throughout the whole series.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |11.22.63|negative|why oh why has stephen king allowed the story line to be changed so much...and certainly not for the better. i enjoyed the book so much but this is a pale imitation. what the hell is the sidekick doing in 1962 and what happened to the very low profile jake epping has to keep? not impressed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |11.22.63|negative|i was extremely disappointed in the mini-series. i should disclose that i read the book but i am not sure i would have liked it any better if that was not the case. i should also disclose that i  am a fan of bad robot jj abrams stephen king and james franco so i was really rooting for a home run here. unfortunately all of the nuance that made you care about the characters and plot in the print version was removed or glossed over in the tv version. i realize there are time constraints that force certain creative decisions but in all honesty i have just finished episode 7 and i don't know if i am rooting for lee harvey oswald or not at this point.  the decisions they made on what to leave and what to trim make no sense. they left in things that were important to the book version but do nothing to further the tv version of the story and removed important elements that would go a long way toward explaining what is going on in the tv version to make room for a story about a janitor no one cares about unless they read the book.. instead of making a tv series that could stand on its own the creators have made a mini-series that is based upon a cliff notes version of the book that is not nearly as good..|
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# root
#  |-- show: string (nullable = true)
#  |-- rating: string (nullable = false)
#  |-- review: string (nullable = true)

# %%
#Carregar tabela Silver em Delta + Hive
(
    df_clean.write
        .format("delta")
        .mode("overwrite")
        .option("overwriteSchema", True)
        .option("path", f"{warehouse_location}/silver.db/audience_reviews")
        .saveAsTable("silver.audience_reviews")
)

print("Tabela silver.audience_reviews carregada com sucesso.")
# Out:
# Tabela silver.audience_reviews carregada com sucesso.

# %%
#Ler Silver para fazer as verificações
df_silver = spark.table("silver.audience_reviews")

print("----- Silver audience_reviews (lida do Hive) -----")
df_silver.show(10, truncate=False)
df_silver.printSchema()
print("Total de linhas na Silver:", df_silver.count())
# Out:
# ----- Silver audience_reviews (lida do Hive) -----
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show    |rating  |review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |11.22.63|negative|"just wasted 8 hours of our lives on this rediculously drawn out ""back to the past"" mini series. nothing about it held up in even given time travel is a fantasy.why james franco would be involved with this stupid project is beyond medon't make the mistake we did!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |11.22.63|negative|king's book is a masterpiece but the series is lousy. its main flaw is in the script; the numerous changes and additions to the book are useless clumsy distracting. much is taken away from the book's plot even parts that would make excellent cinematic material. the original characters are flattened the new ones are poor often inconsistent. the acting of mr. franco is embarrassing. the book was poignant and compelling; the series is a sad travesty of it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |11.22.63|negative|trash! absolute garbage! what a waste of such an amazing story! anyone who has read the book should not watch this as it will only lessen your opinion of 11.22.63 and waste 8 hours of your life. it couldn't have been worse. the story is so twisted from the novel that i wonder how or why stephen king signed off on this pos! yes. it's that bad!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |11.22.63|negative|what a disappointment  so unbalanced like a soap opera from 1963                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |11.22.63|negative|"sure  the lead actors were great as far acting goes i'm cutting to the chase: totally missed the mark on digging into the theories/conflicting stories behind the jfk assassination. this could have been an intriguing concept of time travel had they not filled the episodes full of standard default sub-plots of soap drama junk food. further had the writers stayed the course of focusing in on who all was potentitally involved in this ""conspiracy"" to kill the president again rather than sticking to the life magazine version of the story (that oswald was the lone nut job with the golden bullet) the story could have been powerful. the grassy knoll along with many other possible characters involved was barely even mentioned and or totally left out. either this is just plain embarrassingly bad entertainment or a high mark at what hollywood does best : provide pure propaganda fictions that ultimately become the ""history""  they want us to believe.   but sure  the lead actors were great."                                                                                                                                                                                                                          |
# |11.22.63|negative|crushed the expectations by making it more of a love story than a sci-fi thriller.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |11.22.63|negative|every frame a beautiful portrait - which is a shame because the show itself is so so lame and boring. the book wasn't that great but somehow they managed to make it much much worse.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |11.22.63|negative|performances are subpar pacing is horrible the characters that weren't in the book but added for the series are pointless and distracting. overall disappointing.however compelling enough to keep me watching throughout the whole series.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |11.22.63|negative|why oh why has stephen king allowed the story line to be changed so much...and certainly not for the better. i enjoyed the book so much but this is a pale imitation. what the hell is the sidekick doing in 1962 and what happened to the very low profile jake epping has to keep? not impressed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |11.22.63|negative|i was extremely disappointed in the mini-series. i should disclose that i read the book but i am not sure i would have liked it any better if that was not the case. i should also disclose that i  am a fan of bad robot jj abrams stephen king and james franco so i was really rooting for a home run here. unfortunately all of the nuance that made you care about the characters and plot in the print version was removed or glossed over in the tv version. i realize there are time constraints that force certain creative decisions but in all honesty i have just finished episode 7 and i don't know if i am rooting for lee harvey oswald or not at this point.  the decisions they made on what to leave and what to trim make no sense. they left in things that were important to the book version but do nothing to further the tv version of the story and removed important elements that would go a long way toward explaining what is going on in the tv version to make room for a story about a janitor no one cares about unless they read the book.. instead of making a tv series that could stand on its own the creators have made a mini-series that is based upon a cliff notes version of the book that is not nearly as good..|
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# root
#  |-- show: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- review: string (nullable = true)
#
# Total de linhas na Silver: 65421

# %%
#Verificação de valores nulos
from pyspark.sql import functions as F

print("----- Nulos por coluna (silver.audience_reviews) -----")
df_nulls = df_silver.select([
    F.sum(F.col(c).isNull().cast("int")).alias(c)
    for c in df_silver.columns
])
df_nulls.show()
# Out:
# ----- Nulos por coluna (silver.audience_reviews) -----
# +----+------+------+
# |show|rating|review|
# +----+------+------+
# |   0|     0|     0|
# +----+------+------+

# %%
#Verificação de valores duplicados
print("----- Duplicados (linha inteira) -----")
total_linhas  = df_silver.count()
linhas_unicas = df_silver.dropDuplicates().count()
duplicados    = total_linhas - linhas_unicas

print("Total de linhas:        ", total_linhas)
print("Total de linhas únicas: ", linhas_unicas)
print("Duplicados:             ", duplicados)
# Out:
# ----- Duplicados (linha inteira) -----
# Total de linhas:         65421
# Total de linhas únicas:  65421
# Duplicados:              0

# %%
#Demonstração final
print("----- Demonstração final da Silver audience_reviews (20 linhas) -----")
df_silver.show(20, truncate=False)

print("Total de linhas finais na Silver audience_reviews:", df_silver.count())
# Out:
# ----- Demonstração final da Silver audience_reviews (20 linhas) -----
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show    |rating  |review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |11.22.63|negative|"just wasted 8 hours of our lives on this rediculously drawn out ""back to the past"" mini series. nothing about it held up in even given time travel is a fantasy.why james franco would be involved with this stupid project is beyond medon't make the mistake we did!"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |11.22.63|negative|king's book is a masterpiece but the series is lousy. its main flaw is in the script; the numerous changes and additions to the book are useless clumsy distracting. much is taken away from the book's plot even parts that would make excellent cinematic material. the original characters are flattened the new ones are poor often inconsistent. the acting of mr. franco is embarrassing. the book was poignant and compelling; the series is a sad travesty of it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |11.22.63|negative|trash! absolute garbage! what a waste of such an amazing story! anyone who has read the book should not watch this as it will only lessen your opinion of 11.22.63 and waste 8 hours of your life. it couldn't have been worse. the story is so twisted from the novel that i wonder how or why stephen king signed off on this pos! yes. it's that bad!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |11.22.63|negative|what a disappointment  so unbalanced like a soap opera from 1963                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |11.22.63|negative|"sure  the lead actors were great as far acting goes i'm cutting to the chase: totally missed the mark on digging into the theories/conflicting stories behind the jfk assassination. this could have been an intriguing concept of time travel had they not filled the episodes full of standard default sub-plots of soap drama junk food. further had the writers stayed the course of focusing in on who all was potentitally involved in this ""conspiracy"" to kill the president again rather than sticking to the life magazine version of the story (that oswald was the lone nut job with the golden bullet) the story could have been powerful. the grassy knoll along with many other possible characters involved was barely even mentioned and or totally left out. either this is just plain embarrassingly bad entertainment or a high mark at what hollywood does best : provide pure propaganda fictions that ultimately become the ""history""  they want us to believe.   but sure  the lead actors were great."                                                                                                                                                                                                                          |
# |11.22.63|negative|crushed the expectations by making it more of a love story than a sci-fi thriller.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |11.22.63|negative|every frame a beautiful portrait - which is a shame because the show itself is so so lame and boring. the book wasn't that great but somehow they managed to make it much much worse.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |11.22.63|negative|performances are subpar pacing is horrible the characters that weren't in the book but added for the series are pointless and distracting. overall disappointing.however compelling enough to keep me watching throughout the whole series.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |11.22.63|negative|why oh why has stephen king allowed the story line to be changed so much...and certainly not for the better. i enjoyed the book so much but this is a pale imitation. what the hell is the sidekick doing in 1962 and what happened to the very low profile jake epping has to keep? not impressed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |11.22.63|negative|i was extremely disappointed in the mini-series. i should disclose that i read the book but i am not sure i would have liked it any better if that was not the case. i should also disclose that i  am a fan of bad robot jj abrams stephen king and james franco so i was really rooting for a home run here. unfortunately all of the nuance that made you care about the characters and plot in the print version was removed or glossed over in the tv version. i realize there are time constraints that force certain creative decisions but in all honesty i have just finished episode 7 and i don't know if i am rooting for lee harvey oswald or not at this point.  the decisions they made on what to leave and what to trim make no sense. they left in things that were important to the book version but do nothing to further the tv version of the story and removed important elements that would go a long way toward explaining what is going on in the tv version to make room for a story about a janitor no one cares about unless they read the book.. instead of making a tv series that could stand on its own the creators have made a mini-series that is based upon a cliff notes version of the book that is not nearly as good..|
# |11.22.63|negative|interesting premise for a show but i have no idea what happens when i start a new episode. ridiculous.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |11.22.63|negative|james franco delivers a poor performance as jake in the lead role guy who plays bill is ever increasingly annoying and lee harvey oswald's accent in the show is too difficult to understand.  shocked this received positive reviews.  poor show.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |11.22.63|negative|pretty bad.  poorly paced.  very bad acting by james franco.  some of the supporting actors are pretty good but overall just a poor effort all around.  want something i liked?  in the final episode the yellow card man spins a little story in the car with james franco.  it probably lasts all of a minute.  and yet the actor blows james franco off the screen with his performance.  if the rest had been that good oh boy.  but it isn't.  i simply slogged through the final three episodes to see how it finished and whether it had the same ending as the book or not.  yeesh!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |11.22.63|negative|this thing crashes disastrously somewhere on the 2nd or 3rd part. i can't figure what made king take a perfectly good story flatten the hell out of it make up all these ridiculous side plots that weren't there to begin with and practically kill the story. everything here is just so off. i couldn't even force myself to the last part being so disinterested as i got. do yourself a favor and read the book.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |11.22.63|negative|"i had big expectations about this serie but i'm sorry to say that it's a poor product. everything is so wrong! i know that as a ""constant reader"" you can't expect to find exactly what king has written but the story is so different that makes me sad. franco has only 2 expressions: romantically happy or terrified. gadon is a ninny. the only thing i really like is the secondary cast: webber is a perfect oswald duhamel is a beautifully crazy ex husband and annetto o'toole is such an adorable (and gorgeous) landlord. in the end i'm disappointed."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |11.22.63|negative|a time travel tale gone wrong. like the dead zone 11.22.63 is about assassination. but this time there is time travelling involved to go back to the time when kennedy was killed. no one really cares and the story is not particularly compelling. franco was really bad at playing the lead role. overall it's not something worth wasting 8 hours of your life on.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |11.22.63|negative|after you learn what the objective is in the show you realize that the series is one big plot hole. some interesting situations arise but that might not be enough to fuel me through the last two episodes.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |11.22.63|negative|at about 7 hours it is easy way too long.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |11.22.63|negative|i'm not familiar with the source content but the direction of the show is absurd. you have amazing plot devices at your disposal; time travel a possible conspiracy the cold war the mafia the cia or the potential for some other nefarious group yet we spend 1/2 of the series (4 out of 8 episodes) on domestic abuse? yikes. had me at episode one. lost me by ep. 4.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |11.22.63|negative|interesting premise but execution lacking. the story goes off the rails very quickly and franco becomes just another fanatical nut. and who's this woman and why is she here? a normal person would have reported him to the cops or fbi long ago. great period piece with the authentic cars and costumes and the southern racism. what could have been.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# Total de linhas finais na Silver audience_reviews: 65421
