# %%
pip install ydata-profiling[pyspark]
# Out:
# Requirement already satisfied: ydata-profiling[pyspark] in /opt/conda/lib/python3.11/site-packages (4.17.0)
# WARNING: ydata-profiling 4.17.0 does not provide the extra 'pyspark'
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.11.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (3.7.2)
# Requirement already satisfied: pydantic>=2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (2.12.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (3.1.2)
# Requirement already satisfied: visions[type_image_path]<0.8.2,>=0.7.5 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.24.4)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (4.66.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling[pyspark]) (0.57.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling[pyspark]) (1.4.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling[pyspark]) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[pyspark]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[pyspark]) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling[pyspark]) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[pyspark]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[pyspark]) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/conda/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling[pyspark]) (1.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling[pyspark]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling[pyspark]) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling[pyspark]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2->ydata-profiling[pyspark]) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling[pyspark]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling[pyspark]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling[pyspark]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata-profiling[pyspark]) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[pyspark]) (0.5.3)
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[pyspark]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[pyspark]) (3.1)
# Requirement already satisfied: puremagic in /opt/conda/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[pyspark]) (1.30)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling[pyspark]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark profiling example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/demo/bronze/Rotten_Tomatoes_Movies.csv"

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType, DoubleType

schema= StructType([
    StructField("movie_title", StringType(),True),
    StructField("movie_info", StringType(),True),
    StructField("critics_consensus", StringType(),True),
    StructField("rating", StringType(),True),
    StructField("genre", StringType(),True),
    StructField("directors", StringType(),True),
    StructField("writers", StringType(),True),
    StructField("cast", StringType(),True),
    StructField("in_theaters_date",DateType(),True),
    StructField("on_streaming_date", DateType(),True),
    StructField("runtime_in_minutes", DoubleType(),True),
    StructField("studio_name", StringType(),True),
    StructField("tomatometer_status", StringType(),True),
    StructField("tomatometer_rating", DoubleType(),True),
    StructField("tomatometer_count", IntegerType(),True),
    StructField("audience_rating", DoubleType(),True),
    StructField("audience_count", IntegerType(),True),
    ])

# Read Sillicon valley episodes data to a dataframe
Rotten_Tomatoes_Movies_df = spark.read.csv(hdfs_path, header=True, schema=schema)

# %%
# Note that some profiling operations can resulte in errors due to bad loading options. 
# It is a good praticce start by inspect the schema and a data sample. 
Rotten_Tomatoes_Movies_df.printSchema()
Rotten_Tomatoes_Movies_df.show()
# Out:
# root
#  |-- movie_title: string (nullable = true)
#  |-- movie_info: string (nullable = true)
#  |-- critics_consensus: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- directors: string (nullable = true)
#  |-- writers: string (nullable = true)
#  |-- cast: string (nullable = true)
#  |-- in_theaters_date: date (nullable = true)
#  |-- on_streaming_date: date (nullable = true)
#  |-- runtime_in_minutes: double (nullable = true)
#  |-- studio_name: string (nullable = true)
#  |-- tomatometer_status: string (nullable = true)
#  |-- tomatometer_rating: double (nullable = true)
#  |-- tomatometer_count: integer (nullable = true)
#  |-- audience_rating: double (nullable = true)
#  |-- audience_count: integer (nullable = true)
#
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+-----------------+------------------+--------------------+--------------------+------------------+-----------------+---------------+--------------+
# |         movie_title|          movie_info|   critics_consensus|              rating|               genre|           directors|             writers|                cast|in_theaters_date|on_streaming_date|runtime_in_minutes|         studio_name|  tomatometer_status|tomatometer_rating|tomatometer_count|audience_rating|audience_count|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+-----------------+------------------+--------------------+--------------------+------------------+-----------------+---------------+--------------+
# |Percy Jackson & t...|A teenager discov...|Though it may see...|                  PG|Action & Adventur...|      Chris Columbus|        Craig Titley|Logan Lerman, Bra...|      2010-02-12|       2010-06-29|              83.0|    20th Century Fox|              Rotten|              49.0|              144|           53.0|        254287|
# |         Please Give|Kate has a lot on...|Nicole Holofcener...|                   R|              Comedy|   Nicole Holofcener|   Nicole Holofcener|Catherine Keener,...|      2010-04-30|       2010-10-19|              90.0|Sony Pictures Cla...|     Certified Fresh|              86.0|              140|           64.0|         11567|
# |                  10|"Blake Edwards' 1...|    upon its release| 10 was one of th...|               Rovi"|                null|                   R|     Comedy, Romance|            null|             null|              null|          1979-10-05|          1997-08-27|             118.0|             null|           null|            68|
# |12 Angry Men (Twe...|"A Puerto Rican y...|"" hopes that his...|  an advertising man| doesn't understa...| #2 (John Fiedler...| anxious not to m...| ""go with the fl...|            null|             null|              null| who wrote the 19...| here making his ...|              null|             null|           null|          null|
# |20,000 Leagues Un...|This 1954 Disney ...|One of Disney's f...|                   G|Action & Adventur...|   Richard Fleischer|         Earl Felton|James Mason, Kirk...|      1954-01-01|       2003-05-20|             127.0|              Disney|               Fresh|              89.0|               27|           74.0|         68860|
# |         10,000 B.C.|A young outcast f...|With attention st...|               PG-13|Action & Adventur...|     Roland Emmerich|Roland Emmerich, ...|Steven Strait, Ca...|      2008-03-07|       2008-06-24|             109.0|Warner Bros. Pict...|              Rotten|               8.0|              148|           37.0|        411087|
# |        The 39 Steps|A man in London t...|Packed with twist...|                  NR|Action & Adventur...|    Alfred Hitchcock|Alma Reville, Cha...|Robert Donat, Mad...|      1935-08-01|       1935-06-06|              87.0|Gaumont British D...|     Certified Fresh|              96.0|               47|           86.0|         23827|
# |        3:10 to Yuma|Desperate for mon...|                null|                  NR|Classics, Drama, ...|        Delmer Daves|      Halsted Welles|Glenn Ford, Van H...|      1957-08-07|       2002-04-02|              92.0|   Columbia Pictures|               Fresh|              96.0|               27|           78.0|          9224|
# |Charly (A Heartbe...|Sam Roberts think...|                null|                  PG|Comedy, Drama, Ro...|Adam Thomas Anderegg|Jack Weyland, Jan...|Heather Beers, Ga...|      2002-09-27|       2003-08-01|             103.0| Excel Entertainment|              Rotten|              20.0|               10|           87.0|          4819|
# |     Abraham Lincoln|To date, this D.W...|                null|                  NR|     Classics, Drama|       D.W. Griffith|Gerrit J. Lloyd, ...|Walter Huston, Un...|      1930-11-08|       2008-11-18|              97.0|      United Artists|               Fresh|              90.0|               10|           38.0|           455|
# |          Dark Water|Following up on h...|                null|               PG-13|Art House & Inter...|        Hideo Nakata|Hideo Hakata, Tak...|Hitomi Kuroki, Ri...|      2002-01-19|       2005-06-21|             100.0|    Toho Company Ltd|               Fresh|              80.0|               15|           66.0|         21459|
# |         The Accused|"Simultaneously g...|     Massachusetts."|                null|                   R|Drama, Mystery & ...|     Jonathan Kaplan|           Tom Topor|            null|       1988-10-14|              null|                 110|  Paramount Pictures|              null|               91|           22.0|            79|
# |       The Lost City|Andy Garcia stars...|Its heart is in t...|                   R|               Drama|         Andy Garcia|G. Cabrera Infant...|Andy Garcia, Dust...|      2005-09-03|       2006-08-08|             143.0|   Magnolia Pictures|              Rotten|              25.0|               83|           64.0|         25940|
# |  The Breaking Point|In this taut adap...|                null|                  NR|               Drama|      Michael Curtiz|   Ranald MacDougall|John Garfield, Pa...|      1950-10-06|       2017-08-08|              97.0|   Warner Home Video|               Fresh|             100.0|                7|           84.0|           328|
# |          Adam's Rib|"Written by Ruth ...| while Amanda def...| while the Bonner...|           Tom Ewell| and David Wayne ...| and the return t...| it inspired a br...|            null|             null|              null|        George Cukor|Garson Kanin, Rut...|              null|             null|           null|           100|
# |The Bridge of San...|Thornton Wilder's...|Despite an all-st...|                  PG|Art House & Inter...|      Mary McGuckian|      Mary McGuckian|Gabriel Byrne, F....|      2005-06-10|       2005-10-11|             120.0|  Fine Line Features|              Rotten|               4.0|               24|           35.0|          1931|
# |The Prowler (Cost...|"Webb Garwood (Va...| and they begin a...| conducted while ...| Susan ends the r...| but Garwood rema...| he shoots him an...|  she buys his story|            null|             null|              null| but eventually S...|                null|              null|             null|           null|          null|
# |            Criminal|A contemporary ca...|If you saw Nine Q...|                   R|Drama, Mystery & ...|Greggory Jacobs, ...|Gregory Jacobs, F...|John C. Reilly, D...|      2004-09-24|       2005-04-12|              88.0|Warner Bros. Pict...|               Fresh|              69.0|              124|           57.0|          6702|
# |The Adventures of...|"Will Vinton, the...| Adventures of Ma...|                null|                   G|Action & Adventur...|         Will Vinton|     Susan Shadburne|            null|       1985-03-01|              null|                  86|Eureka Entertainm...|              null|               80|            5.0|            82|
# |           Deep Blue|This comprehensiv...|Full of visually ...|                   G|Documentary, Spec...|Andy Byatt, Alast...|Alastair Fothergi...|Pierce Brosnan, M...|      2005-06-17|       2006-04-11|              90.0|       Miramax Flims|               Fresh|              67.0|               52|           80.0|          4690|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+-----------------+------------------+--------------------+--------------------+------------------+-----------------+---------------+--------------+
# only showing top 20 rows

# %%
# In case of error select a subset of columns until you find the column that causes that.
#For start we can use describe as starting point for data profiling
#For this example the column summary was removed due to a conflit with the first describe column "summary"
Rotten_Tomatoes_Movies_df.describe(['movie_title','movie_info','critics_consensus','rating','genre','directors','writers','cast','in_theaters_date','on_streaming_date','runtime_in_minutes','studio_name','tomatometer_status','tomatometer_rating','tomatometer_count','audience_rating','audience_count']).toPandas()
# Out:
#   summary                                        movie_title  \
# 0   count                                              16638
# 1    mean                                           Infinity
# 2  stddev                                                NaN
# 3     min                              !Women Art Revolution
# 4     max  Ôritsu uchûgun Oneamisu no tsubasa (Royal Spac...
#
#                                           movie_info  \
# 0                                              16614
# 1                                               None
# 2                                               None
# 3  """""George Carlin was once asked how cocaine ...
# 4
#
#                                    critics_consensus  \
# 0                                               9944
# 1                                             2011.0
# 2                                               None
# 3   "" ""The Killing Fields"" and ""Chariots of F...
# 4                                                  🚫
#
#                                               rating  \
# 0                                              16434
# 1                                            1604.75
# 2                                   738.035850529408
# 3   """"The Wedding of the Painted Doll""""-- lat...
# 4  both for Mankiewicz. Based on a novel by John ...
#
#                                                genre  \
# 0                                              16433
# 1                                            1492.25
# 2                                  995.0749971735798
# 3   ""Big G"" has been the object of ridicule sin...
# 4  X-Men: Days of Future Past combines the best e...
#
#                                            directors                writers  \
# 0                                              16363                  15452
# 1                                             1976.5                 2001.0
# 2                                  47.37615433949868                   None
# 3   ""1985"" takes a unique look at a pivotal mom...   ""Baghead"" was born
# 4                                          Øtis Mass             Éva Gárdos
#
#                                                 cast  runtime_in_minutes  \
# 0                                              16236               12416
# 1                                             1994.0  101.90608891752578
# 2                                 28.284271247461902   26.11133339663312
# 3   ""Do you ever just want to get out of this co...                 1.0
# 4  Émile Genest, John Drainie, Tommy Tweed, Sandr...              2000.0
#
#                                          studio_name  tomatometer_status  \
# 0                                              16188               16515
# 1                                 108.72519083969466  101.60266666666666
# 2                                 105.90473097257838  19.846455881383285
# 3   ""Concerto in F"" and the 1935 folk opera Por...    ""A Puzzlement""
# 4           Ákos Ambrus, Imre Madácsi, Attila Pacsay   Zik Zak Filmworks
#
#   tomatometer_rating  tomatometer_count     audience_rating  \
# 0              12918              13277               13394
# 1  60.71450688961139  56.93936883332078   60.05696580558459
# 2   29.3037329320665   64.8540451106354  24.265412407598976
# 3                0.0                  0                 0.0
# 4              222.0                497               448.0
#
#        audience_count
# 0               13765
# 1  123085.34958227388
# 2  1635168.5232283394
# 3                   0
# 4            35797635

# %%
#Select the columns to profile. 
df_to_profile=Rotten_Tomatoes_Movies_df.select("movie_title","movie_info","critics_consensus","rating","genre","directors","writers","cast","in_theaters_date","on_streaming_date","runtime_in_minutes","studio_name","tomatometer_status","tomatometer_rating","tomatometer_count","audience_rating","audience_count")

# %%
import pandas as pd

df_pandas = Rotten_Tomatoes_Movies_df.toPandas()
df_pandas['in_theaters_date'] = pd.to_datetime(df_pandas['in_theaters_date'], errors='coerce')
df_pandas['on_streaming_date'] = pd.to_datetime(df_pandas['on_streaming_date'], errors='coerce')

report = ProfileReport(df_pandas, title="Rotten Tomatoes Movies Profiling", explorative=True)
report.to_file('profile.html')

report = ProfileReport(df_to_profile)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/17 [00:00<?, ?it/s]
#   6%|▌         | 1/17 [00:04<01:13,  4.61s/it]
# 100%|██████████| 17/17 [00:08<00:00,  1.95it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#save profiling report in a file
report.to_file('profile.html')

# %%
#close spark session
spark.stop()
